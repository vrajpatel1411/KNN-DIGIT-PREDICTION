# %%
import numpy as np
import math
from matplotlib import pyplot


def function_of_Beta(Beta):
    sin_value=math.sin(10*math.pi*Beta)
    return (((sin_value)/2*Beta)+(Beta-1)**4)


def derivative_of_Beta(Beta):
    cos_value=math.cos(10*math.pi*Beta)
    inverse=-(2*Beta**2)
    return (((cos_value)/inverse)+4*(Beta-1)**3)

def gradient_descent(learning_rate):
    solutions, scores = list(), list()
    Beta = 2.4
    solutions.append(Beta)
    scores.append(function_of_Beta(Beta)) 
    for k in range(1000):
        Beta = Beta -(learning_rate * derivative_of_Beta(Beta))
        solutions.append(Beta)
        scores.append(function_of_Beta(Beta))
    return solutions,scores


learning_rate=0.01  
solutions,scores=gradient_descent(learning_rate)
bounds=np.arange(0.5,2.6)
results=[]
for i in bounds:
    result = function_of_Beta(i)
    results.append(result)

pyplot.plot(bounds,results)
pyplot.plot(solutions, scores, '.-',color='red')
pyplot.xlabel("range of beta")
pyplot.ylabel("function of beta")
title="Graph where learning rate is "+str(learning_rate)
pyplot.title(title)
pyplot.show()

# %%
learning_rate= 0.1
solutions,scores=gradient_descent(learning_rate)
bounds=np.arange(0.5,2.6)
results=[]
for i in bounds:
    result = function_of_Beta(i)
    results.append(result)

pyplot.plot(bounds,results)
pyplot.plot(solutions, scores, '.-',color='red')
pyplot.xlabel("range of beta")
pyplot.ylabel("function of beta")
title="Graph where learning rate is "+str(learning_rate)
pyplot.title(title)
pyplot.show()

# %%
learning_rate= 0.007
solutions,scores=gradient_descent(learning_rate)
bounds=np.arange(0.5,2.6)
results=[]
for i in bounds:
    result = function_of_Beta(i)
    results.append(result)

pyplot.plot(bounds,results)
pyplot.plot(solutions, scores, '.-',color='red')
pyplot.xlabel("range of beta")
pyplot.ylabel("function of beta")
title="Graph where learning rate is "+str(learning_rate)
pyplot.title(title)
pyplot.show()

# %%
learning_rate= .2
solutions,scores=gradient_descent(learning_rate)
bounds=np.arange(0.5,2.6)
results=[]
for i in bounds:
    result = function_of_Beta(i)
    results.append(result)

pyplot.plot(bounds,results)
pyplot.plot(solutions, scores, '.-',color='red')
pyplot.xlabel("range of beta")
pyplot.ylabel("function of beta")
title="Graph where learning rate is "+str(learning_rate)
pyplot.title(title)
pyplot.show()

# %%
learning_rate= 0.07
solutions,scores=gradient_descent(learning_rate)
bounds=np.arange(0.5,2.6)
results=[]
for i in bounds:
    result = function_of_Beta(i)
    results.append(result)

pyplot.plot(bounds,results)
pyplot.plot(solutions, scores, '.-',color='red')
pyplot.xlabel("range of beta")
pyplot.ylabel("function of beta")
title="Graph where learning rate is "+str(learning_rate)
pyplot.title(title)
pyplot.show()

# %%
learning_rate= 0.005
solutions,scores=gradient_descent(learning_rate)
bounds=np.arange(0.5,2.6)
results=[]
for i in bounds:
    result = function_of_Beta(i)
    results.append(result)

pyplot.plot(bounds,results)
pyplot.plot(solutions, scores, '.-',color='red')
pyplot.xlabel("range of beta")
pyplot.ylabel("function of beta")
title="Graph where learning rate is "+str(learning_rate)
pyplot.title(title)
pyplot.show()
